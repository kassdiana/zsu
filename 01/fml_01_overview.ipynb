# %% [markdown]
# **Fundamentals of Machine Learning - Exercise 1** 💪
# ---

# %% [markdown]
# ---
# ### 🎯 Aim of the Exercise
# -  to become familiar with Jupyter/Google Colab
# -  practice basic data manipulation with Pandas
# -  create simple data visualizations using Pandas, Matplotlib, Seaborn, and eventiually Plotly.

# %% [markdown]
# <br>
#
# <div style="background-color: #05c3de; padding: 20px;">
#     <h2><font color='white'>Explore & Experiment: Cells and Shortcuts </font></h2>
# </div>

# %% [markdown]
# To work efficiently in Jupyter, it's important to understand **how to run cells**, navigate between them and use handy shortcuts.
#
# ---
#
# ### Running a Cell
# You can run a cell in different ways:
#
# - <font color='#05c3de'>**Shift + Enter**</font> → Run the current cell and move to the next one.
# - <font color='#05c3de'>**Ctrl / Command + Enter**</font> → Run the current cell but stay on it.
#
# ---
#
# ### Two Modes in Jupyter
# Jupyter has two operational modes:
#
# ##### 1. <font color='#05c3de'>Edit Mode</font> - for writing and editing cell content.
#
#
#
# ##### 2. <font color='#05c3de'>Command Mode</font> - for navigating and managing cells.
#
#
#
# **Switching Between Modes:**
# - Press **Enter** or click inside of the cell → Activates **Edit Mode**, for typing inside a cell.
# - Press **Esc** or click outside of the cell → Activates **Command Mode**, for manipulation with cells as blocks.
#
# ---
#
# ### Keyboard Shortcuts for Jupyter
# ### <font color='#05c3de'>**Shortcuts in Command Mode**</font>
# You must be in **Command Mode** (Press `Esc` to exit Edit Mode).
#
# | **Shortcut** | **Action** |
# |------------|--------------------------------|
# | <font color='#05c3de'>**A**</font> | Insert a new cell **above** |
# | <font color='#05c3de'>**B**</font> | Insert a new cell **below** |
# | <font color='#05c3de'>**Z**</font> | **Undo delete cell** |
# | <font color='#05c3de'>**D D**</font> (double D) | Delete the selected cell |
# | <font color='#05c3de'>**M**</font> | Convert the cell to **Markdown** |
# | <font color='#05c3de'>**Y**</font> | Convert the cell to **Code** |
#
# ### <font color='#05c3de'>**Shortcuts in Edit Mode**</font>
# You must be in **Edit Mode** (Press `Enter` to enter/activate Edit Mode).
#
# | **Shortcut** | **Action** |
# |------------|--------------------------------|
# | <font color='#05c3de'>**Tab**</font> | Autocomplete code |
# | <font color='#05c3de'>**Shift + Tab**</font> | Show function documentation | <font color='red'>**Ctrl + Home**</font>
# | <font color='#05c3de'>**Ctrl + /**</font> | Toggle comment (add/remove `#`) |

# %% [markdown]
# <div style="background-color: #05c3de; padding: 20px;">
#     <h2><font color='white'>Now, Let´s Python! 🐍</font></h2>
# </div>

# %% [markdown]
# ### **Meet Pandas!** 🐼
# ##### **Not the fluffy animal!** The name *“Pandas”* comes from the term **“Pa**nel **Da**ta”.
#
# Pandas provides convenient tools for working with tabular data using named columns and row indices.
#
# With Pandas, we can easily:
# - load and save tabular data — CSV, Excel, JSON, SQL …
# - select and filter rows and columns
# - clean and transform data
# - combine multiple datasets
# - group and aggregate data
# - reshape datasets

# %% [markdown]
# ## Import library 📘

# %%
import pandas as pd

# %% [markdown]
# ## Loading the Dataset into a Pandas DataFrame 🚴🏻

# %%
df = pd.read_csv("Data/SeoulBikeData_clean.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 df = pd.read_csv("Data/SeoulBikeData_clean.csv")
#
# File c:\Users\Diana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %% [markdown]
# Чтобы загрузить CSV файл, используется функция pd.read_csv(). В ячейке загрузки нужно создать переменную (обычно ее называют df) и передать в функцию путь к твоему файлу

# %% [markdown]
# 💡 **CSV vs. Parquet**
# CSV stores data as plain text and does not preserve data types. Parquet preserves the data schema and uses efficient compression, making it particularly useful for larger datasets.

# %% [markdown]
# <div style="background-color: #05c3de; padding: 10px;">
#     <h2><font color='white'>Exploring the DataFrame 🔍</font></h2>
# </div>

# %% [markdown]
# #### 📑 **The Pandas DataFrame**
#
# *   **2-Dimensional Structure:** A tabular data structure with rows and named columns.
# *   **Heterogeneous Types:**  columns can hold *potentially different* data types (integers, strings, floats, booleans) at the same time.
# *   **Familiar Concept:** You can think of it exactly like an **SQL table** or a spreadsheet.
# *   **Vectorized Operations:** It is the most commonly used Pandas object. We can apply high-performance vectorized functions directly across rows or columns without writing slow Python `for` loops.

# %% [markdown]
# #### First Look at the Data

# %% [markdown]
# #### .head() -  top n rows (default is 5)
# Describe what one row represents?

# %%
df.head()
# Out:
#          Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 0  01/12/2017                254     0         -5.2        37         2.2
# 1  01/12/2017                204     1         -5.5        38         0.8
# 2  01/12/2017                173     2         -6.0        39         1.0
# 3  01/12/2017                107     3         -6.2        40         0.9
# 4  01/12/2017                 78     4         -6.0        36         2.3
#
#    Visibility  Dew_point_temp  Solar_radiation  Rainfall  Snowfall Seasons  \
# 0        2000           -17.6              0.0       0.0       0.0  Winter
# 1        2000           -17.6              0.0       0.0       0.0  Winter
# 2        2000           -17.7              0.0       0.0       0.0  Winter
# 3        2000           -17.6              0.0       0.0       0.0  Winter
# 4        2000           -18.6              0.0       0.0       0.0  Winter
#
#       Holiday Functional_day
# 0  No Holiday            Yes
# ...

# %% [markdown]
# #### .tail() -  bottom n rows (default is 5)

# %%
df.tail()
# Out:
#             Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 8755  30/11/2018               1003    19          4.2        34         2.6
# 8756  30/11/2018                764    20          3.4        37         2.3
# 8757  30/11/2018                694    21          2.6        39         0.3
# 8758  30/11/2018                712    22          2.1        41         1.0
# 8759  30/11/2018                584    23          1.9        43         1.3
#
#       Visibility  Dew_point_temp  Solar_radiation  Rainfall  Snowfall Seasons  \
# 8755        1894           -10.3              0.0       0.0       0.0  Autumn
# 8756        2000            -9.9              0.0       0.0       0.0  Autumn
# 8757        1968            -9.9              0.0       0.0       0.0  Autumn
# 8758        1859            -9.8              0.0       0.0       0.0  Autumn
# 8759        1909            -9.3              0.0       0.0       0.0  Autumn
#
#          Holiday Functional_day
# ...

# %% [markdown]
# #### .sample() -  random n rows

# %%
df.sample()
# Out:
#             Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 4582  09/06/2018                776    22         21.0        75         1.3
#
#       Visibility  Dew_point_temp  Solar_radiation  Rainfall  Snowfall Seasons  \
# 4582        2000            16.3              0.0       0.0       0.0  Summer
#
#          Holiday Functional_day
# 4582  No Holiday            Yes

# %% [markdown]
# 💡By default, sample() returns a different random sample each time it is called

# %%
df.sample(5, random_state=42)
# Out:
#             Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 6056  10/08/2018               1728     8         27.2        69         1.8
# 5556  20/07/2018                822    12         32.6        51         2.1
# 5990  07/08/2018                658    14         34.0        50         1.2
# 7674  16/10/2018               2716    18         16.9        47         1.4
# 3319  18/04/2018               1083     7          6.4        51         1.0
#
#       Visibility  Dew_point_temp  Solar_radiation  Rainfall  Snowfall Seasons  \
# 6056        1999            21.0             0.70       0.0       0.0  Summer
# 5556         800            21.1             3.21       0.0       0.0  Summer
# 5990        1744            22.1             1.68       0.0       0.0  Summer
# 7674        1637             5.5             0.11       0.0       0.0  Autumn
# 3319        1398            -3.0             0.19       0.0       0.0  Spring
#
#          Holiday Functional_day
# ...

# %% [markdown]
# 💡 Setting random_state makes the random selection reproducible — the same rows will be selected each time.

# %% [markdown]
# .head() и .tail(): Выводят первые или последние строки. По умолчанию — 5 строк, но можно передать любое число в скобки (например, df.head(10)).
#
# .sample(): Выдает случайные строки. Это полезно, чтобы посмотреть данные из разных частей таблицы, а не только отсортированные с начала.
# Без random_state (например, просто df.sample(5)): Каждый раз, когда вы запускаете эту строчку, компьютер будет выдавать вам 5 разных строк.
#
# С random_state=42: Компьютер зафиксирует алгоритм выбора. Если вы запустите этот код сейчас, завтра или через год на другом компьютере — вы получите одни и те же 5 строк.
#
# Зачем это нужно?
# В анализе данных и машинном обучении критически важно получать одинаковые результаты при повторных запусках одного и того же кода. Если вы делите данные на обучающую и тестовую выборки, вы хотите, чтобы при перезапуске программы (или когда ваш код запустит коллега) данные разделились точно так же, иначе результаты экспериментов будет невозможно сравнить.

# %% [markdown]
# ### Exploring Categorical Columns
#
# For categorical columns, we can inspect the unique values and how often they occur.

# %%
df["Seasons"].unique()
# Out:
# <StringArray>
# ['Winter', 'Spring', 'Summer', 'Autumn']
# Length: 4, dtype: str

# %%
df["Seasons"].value_counts()
# Out:
# Seasons
# Spring    2208
# Summer    2208
# Autumn    2184
# Winter    2160
# Name: count, dtype: int64

# %%
df["Holiday"].value_counts()
# Out:
# Holiday
# No Holiday    8328
# Holiday        432
# Name: count, dtype: int64

# %% [markdown]
# unique() отвечает на вопрос «ЧТО здесь есть?», а value_counts() отвечает на вопрос «СКОЛЬКО раз каждое из них встречается?».

# %% [markdown]
# #### DataFrame Shape

# %%
df.shape
# Out:
# (8760, 14)

# %% [markdown]
# DataFrame Shape: Показывает размерность таблицы (строки, столбцы). В отличие от методов выше, shape — это атрибут, а не функция, поэтому скобки писать не нужно.

# %% [markdown]
# 💡Notice that "shape" is an attribute containing a tuple, not a method, so it is accessed without parentheses.

# %% [markdown]
# #### Data Types

# %%
df.dtypes
# Out:
# Date                     str
# Rented_bike_count      int64
# Hour                   int64
# Temperature          float64
# Humidity               int64
# Wind_speed           float64
# Visibility             int64
# Dew_point_temp       float64
# Solar_radiation      float64
# Rainfall             float64
# Snowfall             float64
# Seasons                  str
# Holiday                  str
# Functional_day           str
# dtype: object

# %% [markdown]
# #### DataFrame Summary
# Use `info()`.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               8760 non-null   str
#  1   Rented_bike_count  8760 non-null   int64
#  2   Hour               8760 non-null   int64
#  3   Temperature        8760 non-null   float64
#  4   Humidity           8760 non-null   int64
#  5   Wind_speed         8760 non-null   float64
#  6   Visibility         8760 non-null   int64
#  7   Dew_point_temp     8760 non-null   float64
#  8   Solar_radiation    8760 non-null   float64
#  9   Rainfall           8760 non-null   float64
#  10  Snowfall           8760 non-null   float64
#  11  Seasons            8760 non-null   str
#  12  Holiday            8760 non-null   str
#  13  Functional_day     8760 non-null   str
# dtypes: float64(6), int64(4), str(4)
# memory usage: 958.3 KB

# %% [markdown]
# 💡.info() also provides information about the DataFrame's memory usage df.info(memory_usage="deep")

# %% [markdown]
# Чтобы посмотреть типы данных всех колонок - df.dtypes. Для получения полной сводки (включая количество непустых значений и использование памяти) - df.info().

# %% [markdown]
# 🧩 Which column has an unsuitable data type, and why?

# %% [markdown]
# 🧩 Let's check whether the dataset contains any missing values. Use `isna().sum()`.

# %%
df.isna().sum()
# Out:
# Date                 0
# Rented_bike_count    0
# Hour                 0
# Temperature          0
# Humidity             0
# Wind_speed           0
# Visibility           0
# Dew_point_temp       0
# Solar_radiation      0
# Rainfall             0
# Snowfall             0
# Seasons              0
# Holiday              0
# Functional_day       0
# dtype: int64

# %% [markdown]
# Метод isna() возвращает таблицу такого же размера, состоящую из True (пусто) и False (не пусто). Метод sum() складывает эти логические значения по колонкам (где True = 1, False = 0), показывая точное количество пропусков.

# %% [markdown]
# <div style="background-color: #05c3de; padding: 10px;">
#     <h2><font color='white'>Datetime format 📅 </font></h2>
# </div>

# %% [markdown]
# 💡We noticed that the Date column is not stored as a string (str). Let's convert it to a proper datetime format with `pd.to_datetime`; the date format is `%d/%m/%Y`. Then verify the column's data type.

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%d/%m/%Y")

# %%
df["Date"].dtype
# Out:
# dtype('<M8[us]')

# %% [markdown]
# Если колонка с датой имеет тип object (строка), датафрейм не сможет извлекать из нее месяцы или дни недели. Функция pd.to_datetime() конвертирует текст в объекты дат по указанному формату.

# %% [markdown]
# <div style="background-color: #05c3de; padding: 10px;">
#     <h2><font color='white'>Basic numerical stats</font></h2>
# </div>

# %% [markdown]
# ### .describe() - basic statistics on numerical columns

# %%
df.describe()
# Out:
#                       Date  Rented_bike_count         Hour  Temperature  \
# count                 8760        8760.000000  8760.000000  8760.000000
# mean   2018-06-01 00:00:00         704.602055    11.500000    12.882922
# min    2017-12-01 00:00:00           0.000000     0.000000   -17.800000
# 25%    2018-03-02 00:00:00         191.000000     5.750000     3.500000
# 50%    2018-06-01 00:00:00         504.500000    11.500000    13.700000
# 75%    2018-08-31 00:00:00        1065.250000    17.250000    22.500000
# max    2018-11-30 00:00:00        3556.000000    23.000000    39.400000
# std                    NaN         644.997468     6.922582    11.944825
#
#           Humidity   Wind_speed   Visibility  Dew_point_temp  Solar_radiation  \
# count  8760.000000  8760.000000  8760.000000     8760.000000      8760.000000
# mean     58.226256     1.724909  1436.825799        4.073813         0.569111
# min       0.000000     0.000000    27.000000      -30.600000         0.000000
# ...

# %% [markdown]
# 💡 By default, describe() summarizes only numerical columns. You can use <code>include="all"</code> to include all columns, including string columns.

# %%
df.describe(include="all")
# Out:
#                        Date  Rented_bike_count         Hour  Temperature  \
# count                  8760        8760.000000  8760.000000  8760.000000
# unique                  NaN                NaN          NaN          NaN
# top                     NaN                NaN          NaN          NaN
# freq                    NaN                NaN          NaN          NaN
# mean    2018-06-01 00:00:00         704.602055    11.500000    12.882922
# min     2017-12-01 00:00:00           0.000000     0.000000   -17.800000
# 25%     2018-03-02 00:00:00         191.000000     5.750000     3.500000
# 50%     2018-06-01 00:00:00         504.500000    11.500000    13.700000
# 75%     2018-08-31 00:00:00        1065.250000    17.250000    22.500000
# max     2018-11-30 00:00:00        3556.000000    23.000000    39.400000
# std                     NaN         644.997468     6.922582    11.944825
#
#            Humidity   Wind_speed   Visibility  Dew_point_temp  \
# ...

# %% [markdown]
# Команда df.describe() выводит базовую описательную статистику для всех числовых колонок в датафрейме. Это один из главных способов быстро посмотреть, как распределены данные.
#
# В результате вы получите таблицу, где колонки — это числовые признаки из данных, а строки — статистические метрики:
#
# count — количество непустых (не NaN) значений. Помогает сразу увидеть, в каких колонках не хватает данных.
#
# mean — среднее арифметическое значение.
#
# std (standard deviation) — стандартное отклонение. Показывает, насколько сильно значения «разбросаны» вокруг среднего. Чем больше std, тем сильнее разброс.
#
# min — минимальное значение в колонке.
#
# 25% (первый квартиль) — значение, ниже которого находится 25% всех данных.
#
# 50% (медиана) — значение, которое делит данные пополам. Половина значений меньше медианы, половина — больше. Часто это более показательная метрика, чем mean, так как она не искажается экстремальными выбросами.
#
# 75% (третий квартиль) — значение, ниже которого находится 75% данных.
#
# max — максимальное значение.
#
# Зачем это нужно?
# Эта команда помогает за пару секунд найти аномалии и выбросы перед началом анализа. Например:
#
# Если в колонке «Возраст клиента» min равен -5 или max равен 150 — сразу понятно, что в данных есть ошибки.
#
# Если count в одной колонке 1000, а в другой 850 — значит, во второй есть 150 пропущенных значений.
#
# Важный нюанс: По умолчанию describe() игнорирует текстовые (категориальные) колонки и анализирует только числа. Если нужна статистика по текстовым колонкам (количество уникальных значений, самое частое значение), нужно написать df.describe(include='object') или df.describe(include='all').

# %% [markdown]
# <div style="background-color: #05c3de; padding: 10px;">
#     <h2><font color='white'>Selecting data from Pandas dataframes </font></h2>
# </div>

# %% [markdown]
# ## <font color='#05c3de'>loc - iloc</font>
#
# - <code>loc</code>: selects data by **labels**
# - <code>iloc</code>: selects data by **integer positions**

# %% [markdown]
# ## <code>loc</code>
# ### data.loc [row_labels, column_labels]

# %% [markdown]
# Это два главных инструмента для срезов (slicing) данных. Разница между ними принципиальна:
#
# loc ищет по именам (меткам). Если у тебя стандартный индекс (0, 1, 2...), то loc[5] выдаст строку с названием 5. При срезах (например, 0:5) loc включает последнее значение (выдаст строки от 0 до 5 включительно).
#
# iloc ищет по позициям (как индексы в массивах C/C++). Срез 0:5 не включает последнее значение (выдаст строки на позициях 0, 1, 2, 3, 4). Сюда можно передавать отрицательные индексы (например, -1 для последней строки или колонки).

# %% [markdown]
# 🧩 Let's select the value in the row with label 0 and the Rented_bike_count column.

# %%
df.loc[0, "Rented_bike_count"]
# Out:
# np.int64(254)

# %% [markdown]
# 🧩 Select all rows from the beginning up to label 5

# %%
df.loc[:5]
# Out:
#         Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 0 2017-12-01                254     0         -5.2        37         2.2
# 1 2017-12-01                204     1         -5.5        38         0.8
# 2 2017-12-01                173     2         -6.0        39         1.0
# 3 2017-12-01                107     3         -6.2        40         0.9
# 4 2017-12-01                 78     4         -6.0        36         2.3
# 5 2017-12-01                100     5         -6.4        37         1.5
#
#    Visibility  Dew_point_temp  Solar_radiation  Rainfall  Snowfall Seasons  \
# 0        2000           -17.6              0.0       0.0       0.0  Winter
# 1        2000           -17.6              0.0       0.0       0.0  Winter
# 2        2000           -17.7              0.0       0.0       0.0  Winter
# 3        2000           -17.6              0.0       0.0       0.0  Winter
# 4        2000           -18.6              0.0       0.0       0.0  Winter
# ...

# %% [markdown]
# 💡 If the slice starts from the beginning, the first label can be omitted.
# 💡 With <code>loc</code>, the end label is included.

# %% [markdown]
# 🧩 Select the "Temperature" column for rows with labels from 0 to 5

# %%
df.loc[:5, "Temperature"]
# Out:
# 0   -5.2
# 1   -5.5
# 2   -6.0
# 3   -6.2
# 4   -6.0
# 5   -6.4
# Name: Temperature, dtype: float64

# %% [markdown]
# 💡Output is 'series'

# %% [markdown]
# 🧩 Let's select the Date, Rented_bike_count, and Temperature columns for rows with labels 0 to 5.

# %%
df.loc[:5, ["Date", "Rented_bike_count", "Temperature"]]
# Out:
#         Date  Rented_bike_count  Temperature
# 0 2017-12-01                254         -5.2
# 1 2017-12-01                204         -5.5
# 2 2017-12-01                173         -6.0
# 3 2017-12-01                107         -6.2
# 4 2017-12-01                 78         -6.0
# 5 2017-12-01                100         -6.4

# %% [markdown]
# 💡  When columns are provided as a list -> output is DataFrame

# %% [markdown]
# - We can access multiple columnns

# %% [markdown]
# 🧩 Select rows 0, 2, and 4 and columns "Date","Rented_bike_count" and "Temperature".

# %%
df.loc[[0, 2, 4], ["Date", "Rented_bike_count", "Temperature"]]
# Out:
#         Date  Rented_bike_count  Temperature
# 0 2017-12-01                254         -5.2
# 2 2017-12-01                173         -6.0
# 4 2017-12-01                 78         -6.0

# %% [markdown]
# ## <code>iloc</code>
# ### data.iloc [row_positions, column_positions]

# %% [markdown]
# 🧩 Let's select the value in the first row and the second column.

# %%
df.iloc[1, 2]
# Out:
# np.int64(1)

# %% [markdown]
# 🧩 Let's select the first 5 rows and the first 4 columns.

# %%
df.iloc[:5, :4]
# Out:
#         Date  Rented_bike_count  Hour  Temperature
# 0 2017-12-01                254     0         -5.2
# 1 2017-12-01                204     1         -5.5
# 2 2017-12-01                173     2         -6.0
# 3 2017-12-01                107     3         -6.2
# 4 2017-12-01                 78     4         -6.0

# %% [markdown]
# 💡 With <code>iloc</code>, the end position is excluded.

# %% [markdown]
# 🧩 Select all rows from the last column

# %%
df.iloc[:, -1:]
# Out:
#      Functional_day
# 0               Yes
# 1               Yes
# 2               Yes
# 3               Yes
# 4               Yes
# ...             ...
# 8755            Yes
# 8756            Yes
# 8757            Yes
# 8758            Yes
# 8759            Yes
#
# [8760 rows x 1 columns]

# %% [markdown]
# 🧩 Let's select the last 5 rows and the last 3 columns.

# %%
df.iloc[-5:, -3:]
# Out:
#      Seasons     Holiday Functional_day
# 8755  Autumn  No Holiday            Yes
# 8756  Autumn  No Holiday            Yes
# 8757  Autumn  No Holiday            Yes
# 8758  Autumn  No Holiday            Yes
# 8759  Autumn  No Holiday            Yes

# %% [markdown]
# 🧩 Select last row, all columns

# %%
df.iloc[-1:, :]
# Out:
#            Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 8759 2018-11-30                584    23          1.9        43         1.3
#
#       Visibility  Dew_point_temp  Solar_radiation  Rainfall  Snowfall Seasons  \
# 8759        1909            -9.3              0.0       0.0       0.0  Autumn
#
#          Holiday Functional_day
# 8759  No Holiday            Yes

# %%
#data.iloc[:, -2]     # second-to-last column
#data.iloc[:, -2:]    # last two columns
#data.iloc[:, -3:]   # last three columns

# %% [markdown]
# 🧩 Select the first 5 rows and the Date, Hour, and Temperature columns using their positions.

# %%
df.iloc[:5, [0, 2, 3]]
# Out:
#         Date  Hour  Temperature
# 0 2017-12-01     0         -5.2
# 1 2017-12-01     1         -5.5
# 2 2017-12-01     2         -6.0
# 3 2017-12-01     3         -6.2
# 4 2017-12-01     4         -6.0

# %% [markdown]
# 🧩 Let's select the last 5 rows and the last 2 columns

# %%
df.iloc[-5:, -2:]
# Out:
#          Holiday Functional_day
# 8755  No Holiday            Yes
# 8756  No Holiday            Yes
# 8757  No Holiday            Yes
# 8758  No Holiday            Yes
# 8759  No Holiday            Yes

# %% [markdown]
# ### Quick CheatSheet
#
# | Action                  | `loc` – By Label                        | `iloc` – By Position    |
# | ----------------------- | --------------------------------------- | ----------------------- |
# | Select a single row     | `data.loc[2]`                           | `data.iloc[2]`          |
# | Select a single column  | `data.loc[:, "Temperature"]`            | `data.iloc[:, 3]`       |
# | Select multiple rows    | `data.loc[[1, 3, 5]]`                   | `data.iloc[[1, 3, 5]]`  |
# | Select multiple columns | `data.loc[:, ["Date", "Temperature"]]`  | `data.iloc[:, [0, 3]]`  |
# | Select a range of rows  | `data.loc[:5]`                          | `data.iloc[:5]`         |
# | Select rows and columns | `data.loc[:5, ["Date", "Temperature"]]` | `data.iloc[:5, [0, 3]]` |
# | Select from the end     | —                                       | `data.iloc[-5:, -2:]`   |

# %% [markdown]
# <div style="background-color: #05c3de; padding: 10px;">
#     <h2><font color='white'>Series vs Dataframe </font></h2>
# </div>

# %% [markdown]
# - #### A Pandas Series is a one-dimensional labeled array
# - #### We can select a single column in several ways - output is a Series

# %%
df.Rented_bike_count
# Out:
# 0        254
# 1        204
# 2        173
# 3        107
# 4         78
#         ...
# 8755    1003
# 8756     764
# 8757     694
# 8758     712
# 8759     584
# Name: Rented_bike_count, Length: 8760, dtype: int64

# %%
df["Rented_bike_count"]
# Out:
# 0        254
# 1        204
# 2        173
# 3        107
# 4         78
#         ...
# 8755    1003
# 8756     764
# 8757     694
# 8758     712
# 8759     584
# Name: Rented_bike_count, Length: 8760, dtype: int64

# %%
df.loc[:, "Rented_bike_count"]
# Out:
# 0        254
# 1        204
# 2        173
# 3        107
# 4         78
#         ...
# 8755    1003
# 8756     764
# 8757     694
# 8758     712
# 8759     584
# Name: Rented_bike_count, Length: 8760, dtype: int64

# %% [markdown]
# 💡Using double brackets returns a `DataFrame`, even when selecting a single column.

# %%
df[["Rented_bike_count"]]
# Out:
#       Rented_bike_count
# 0                   254
# 1                   204
# 2                   173
# 3                   107
# 4                    78
# ...                 ...
# 8755               1003
# 8756                764
# 8757                694
# 8758                712
# 8759                584
#
# [8760 rows x 1 columns]

# %% [markdown]
# <div style="background-color: #05c3de; padding: 10px;">
#     <h2><font color='white'>Filtering Data 🔽</font></h2>
# </div>

# %% [markdown]
# 🧩 Let's see which rows have temperatures above 25 °C.

# %%
df["Temperature"] > 25
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8755    False
# 8756    False
# 8757    False
# 8758    False
# 8759    False
# Name: Temperature, Length: 8760, dtype: bool

# %% [markdown]
# 💡 The condition returns a Boolean `Series` containing `True` or `False` for each row.

# %% [markdown]
# 🧩 Let's count how many rows have temperatures above 25 °C.

# %%
(df["Temperature"] > 25).sum()
# Out:
# np.int64(1502)

# %% [markdown]
# 🧩 Let's select the rows where the temperature is above 25 °C.

# %%
df[df["Temperature"] > 25]
# Out:
#            Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 3374 2018-04-20                970    14         25.9        28         2.2
# 3375 2018-04-20               1080    15         26.1        27         1.8
# 3376 2018-04-20               1206    16         25.7        30         3.4
# 3377 2018-04-20               1543    17         25.6        30         2.3
# 3785 2018-05-07               2392    17         25.5        31         2.3
# ...         ...                ...   ...          ...       ...         ...
# 7263 2018-09-29               2065    15         26.5        33         1.4
# 7264 2018-09-29               2254    16         26.6        34         1.3
# 7265 2018-09-29               2432    17         26.3        31         1.0
# 7383 2018-10-04                  0    15         25.3        39         1.6
# 7384 2018-10-04                  0    16         25.1        41         1.0
#
# ...

# %% [markdown]
# 💡Only rows where the condition is `True` are selected.

# %% [markdown]
# - ### Boolean mask

# %%
mask = df["Temperature"] > 25

# %%
mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8755    False
# 8756    False
# 8757    False
# 8758    False
# 8759    False
# Name: Temperature, Length: 8760, dtype: bool

# %%
df[mask]
# Out:
#            Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 3374 2018-04-20                970    14         25.9        28         2.2
# 3375 2018-04-20               1080    15         26.1        27         1.8
# 3376 2018-04-20               1206    16         25.7        30         3.4
# 3377 2018-04-20               1543    17         25.6        30         2.3
# 3785 2018-05-07               2392    17         25.5        31         2.3
# ...         ...                ...   ...          ...       ...         ...
# 7263 2018-09-29               2065    15         26.5        33         1.4
# 7264 2018-09-29               2254    16         26.6        34         1.3
# 7265 2018-09-29               2432    17         26.3        31         1.0
# 7383 2018-10-04                  0    15         25.3        39         1.6
# 7384 2018-10-04                  0    16         25.1        41         1.0
#
# ...

# %% [markdown]
# 💡 Pandas checks the condition for each value in the selected column and returns True or False.
# When the mask is applied to the DataFrame, only the rows where the mask is True are kept.

# %% [markdown]
# ### Cheat Sheet: Comparison Operators
#
# | Operator | Meaning                  |
# | -------- | ------------------------ |
# | `==`     | Equal to                 |
# | `!=`     | Not equal to             |
# | `>`      | Greater than             |
# | `<`      | Less than                |
# | `>=`     | Greater than or equal to |
# | `<=`     | Less than or equal to    |

# %% [markdown]
# 🧩 Let's select only the observations from summer using a Boolean mask.

# %%
mask = df["Seasons"] == "Summer"
df[mask]
# Out:
#            Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 4368 2018-06-01                963     0         20.1        63         1.1
# 4369 2018-06-01                776     1         19.5        65         0.4
# 4370 2018-06-01                554     2         19.0        72         1.4
# 4371 2018-06-01                366     3         18.6        72         1.4
# 4372 2018-06-01                265     4         18.1        76         1.8
# ...         ...                ...   ...          ...       ...         ...
# 6571 2018-08-31               2372    19         26.5        69         2.3
# 6572 2018-08-31               1995    20         25.4        74         1.6
# 6573 2018-08-31               1931    21         24.5        78         1.2
# 6574 2018-08-31               1789    22         24.1        80         0.9
# 6575 2018-08-31               1329    23         23.8        81         0.6
#
# ...

# %% [markdown]
# 🧩  Let's select all observations that are not from summer.

# %%
mask = df["Seasons"] != "Summer"
df[mask]
# Out:
#            Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 0    2017-12-01                254     0         -5.2        37         2.2
# 1    2017-12-01                204     1         -5.5        38         0.8
# 2    2017-12-01                173     2         -6.0        39         1.0
# 3    2017-12-01                107     3         -6.2        40         0.9
# 4    2017-12-01                 78     4         -6.0        36         2.3
# ...         ...                ...   ...          ...       ...         ...
# 8755 2018-11-30               1003    19          4.2        34         2.6
# 8756 2018-11-30                764    20          3.4        37         2.3
# 8757 2018-11-30                694    21          2.6        39         0.3
# 8758 2018-11-30                712    22          2.1        41         1.0
# 8759 2018-11-30                584    23          1.9        43         1.3
#
# ...

# %%
df[df["Seasons"] != "Summer"]
# Out:
#            Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 0    2017-12-01                254     0         -5.2        37         2.2
# 1    2017-12-01                204     1         -5.5        38         0.8
# 2    2017-12-01                173     2         -6.0        39         1.0
# 3    2017-12-01                107     3         -6.2        40         0.9
# 4    2017-12-01                 78     4         -6.0        36         2.3
# ...         ...                ...   ...          ...       ...         ...
# 8755 2018-11-30               1003    19          4.2        34         2.6
# 8756 2018-11-30                764    20          3.4        37         2.3
# 8757 2018-11-30                694    21          2.6        39         0.3
# 8758 2018-11-30                712    22          2.1        41         1.0
# 8759 2018-11-30                584    23          1.9        43         1.3
#
# ...

# %% [markdown]
# #### Combining Multiple Conditions
#
# | Operator | Meaning |
# | -------- | ------- |
# | `&`      | AND     |
# | `\|`     | OR      |
# | `~`      | NOT     |

# %% [markdown]
# 🧩 Let's select observations where the temperature is above 25 °C and the humidity is below 60%.

# %%
mask = (df["Temperature"] > 25) & (df["Humidity"] < 60)
df[mask]
# Out:
#            Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 3374 2018-04-20                970    14         25.9        28         2.2
# 3375 2018-04-20               1080    15         26.1        27         1.8
# 3376 2018-04-20               1206    16         25.7        30         3.4
# 3377 2018-04-20               1543    17         25.6        30         2.3
# 3785 2018-05-07               2392    17         25.5        31         2.3
# ...         ...                ...   ...          ...       ...         ...
# 7263 2018-09-29               2065    15         26.5        33         1.4
# 7264 2018-09-29               2254    16         26.6        34         1.3
# 7265 2018-09-29               2432    17         26.3        31         1.0
# 7383 2018-10-04                  0    15         25.3        39         1.6
# 7384 2018-10-04                  0    16         25.1        41         1.0
#
# ...

# %% [markdown]
# 🧩 Let's select observations where the temperature is above 25 °C or the humidity is above 80%.

# %%
mask = (df["Temperature"] > 25) | (df["Humidity"] < 60)
df[mask]
# Out:
#            Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 0    2017-12-01                254     0         -5.2        37         2.2
# 1    2017-12-01                204     1         -5.5        38         0.8
# 2    2017-12-01                173     2         -6.0        39         1.0
# 3    2017-12-01                107     3         -6.2        40         0.9
# 4    2017-12-01                 78     4         -6.0        36         2.3
# ...         ...                ...   ...          ...       ...         ...
# 8755 2018-11-30               1003    19          4.2        34         2.6
# 8756 2018-11-30                764    20          3.4        37         2.3
# 8757 2018-11-30                694    21          2.6        39         0.3
# 8758 2018-11-30                712    22          2.1        41         1.0
# 8759 2018-11-30                584    23          1.9        43         1.3
#
# ...

# %% [markdown]
# 💡 When combining multiple conditions, put each condition in parentheses ().

# %% [markdown]
# 🧩 Let's select observations that are not from summer.

# %%
mask = ~(df["Seasons"] == "Summer")
df[mask]
# Out:
#            Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 0    2017-12-01                254     0         -5.2        37         2.2
# 1    2017-12-01                204     1         -5.5        38         0.8
# 2    2017-12-01                173     2         -6.0        39         1.0
# 3    2017-12-01                107     3         -6.2        40         0.9
# 4    2017-12-01                 78     4         -6.0        36         2.3
# ...         ...                ...   ...          ...       ...         ...
# 8755 2018-11-30               1003    19          4.2        34         2.6
# 8756 2018-11-30                764    20          3.4        37         2.3
# 8757 2018-11-30                694    21          2.6        39         0.3
# 8758 2018-11-30                712    22          2.1        41         1.0
# 8759 2018-11-30                584    23          1.9        43         1.3
#
# ...

# %% [markdown]
# 💡 The ~ operator negates a Boolean condition: True becomes False and False becomes True.

# %% [markdown]
# - #### Filtering with loc

# %% [markdown]
# 🧩 Let's select the Date, Hour, Temperature, and Rented_bike_count columns for observations where the temperature is above 25 °C.

# %%
mask = df["Temperature"] > 25

df.loc[mask, ["Date", "Hour", "Temperature", "Rented_bike_count"]]
# Out:
#            Date  Hour  Temperature  Rented_bike_count
# 3374 2018-04-20    14         25.9                970
# 3375 2018-04-20    15         26.1               1080
# 3376 2018-04-20    16         25.7               1206
# 3377 2018-04-20    17         25.6               1543
# 3785 2018-05-07    17         25.5               2392
# ...         ...   ...          ...                ...
# 7263 2018-09-29    15         26.5               2065
# 7264 2018-09-29    16         26.6               2254
# 7265 2018-09-29    17         26.3               2432
# 7383 2018-10-04    15         25.3                  0
# 7384 2018-10-04    16         25.1                  0
#
# [1502 rows x 4 columns]

# %% [markdown]
# 💡 With loc, we can use a Boolean mask to filter rows and select specific columns at the same time.

# %% [markdown]
# - ### Creating a Subset

# %% [markdown]
# We can store the filtered data in a new variable and work with it separately.

# %%
mask = df["Temperature"] > 25

hot_days = df.loc[mask,["Date", "Hour", "Temperature", "Rented_bike_count"]].copy()

# %% [markdown]
# 💡 .copy() creates an independent copy of the selected data, which is useful if we want to modify the subset later without affecting the original DataFrame.

# %%
hot_days
# Out:
#            Date  Hour  Temperature  Rented_bike_count
# 3374 2018-04-20    14         25.9                970
# 3375 2018-04-20    15         26.1               1080
# 3376 2018-04-20    16         25.7               1206
# 3377 2018-04-20    17         25.6               1543
# 3785 2018-05-07    17         25.5               2392
# ...         ...   ...          ...                ...
# 7263 2018-09-29    15         26.5               2065
# 7264 2018-09-29    16         26.6               2254
# 7265 2018-09-29    17         26.3               2432
# 7383 2018-10-04    15         25.3                  0
# 7384 2018-10-04    16         25.1                  0
#
# [1502 rows x 4 columns]

# %% [markdown]
# .reset_index()

# %%
hot_days.reset_index()
# Out:
#       index       Date  Hour  Temperature  Rented_bike_count
# 0      3374 2018-04-20    14         25.9                970
# 1      3375 2018-04-20    15         26.1               1080
# 2      3376 2018-04-20    16         25.7               1206
# 3      3377 2018-04-20    17         25.6               1543
# 4      3785 2018-05-07    17         25.5               2392
# ...     ...        ...   ...          ...                ...
# 1497   7263 2018-09-29    15         26.5               2065
# 1498   7264 2018-09-29    16         26.6               2254
# 1499   7265 2018-09-29    17         26.3               2432
# 1500   7383 2018-10-04    15         25.3                  0
# 1501   7384 2018-10-04    16         25.1                  0
#
# [1502 rows x 5 columns]

# %% [markdown]
# Эта команда создает новый красивый индекс по порядку (0, 1, 2, 3...), а старый индекс превращает в обычную колонку и добавляет ее в вашу таблицу (обычно колонка так и называется — index).
#
# Зачем нужно: Это полезно, если в старом индексе хранилась важная информация, которую вы не хотите потерять. Например, если индексами были названия городов или даты, и вы хотите перенести их внутрь таблицы для дальнейшей работы.

# %% [markdown]
# 🧩 What happened to the original index?

# %%
hot_days.reset_index(drop=True)
# Out:
#            Date  Hour  Temperature  Rented_bike_count
# 0    2018-04-20    14         25.9                970
# 1    2018-04-20    15         26.1               1080
# 2    2018-04-20    16         25.7               1206
# 3    2018-04-20    17         25.6               1543
# 4    2018-05-07    17         25.5               2392
# ...         ...   ...          ...                ...
# 1497 2018-09-29    15         26.5               2065
# 1498 2018-09-29    16         26.6               2254
# 1499 2018-09-29    17         26.3               2432
# 1500 2018-10-04    15         25.3                  0
# 1501 2018-10-04    16         25.1                  0
#
# [1502 rows x 4 columns]

# %% [markdown]
# параметр drop=True означает «удали старый индекс насовсем». Старый индекс исчезает и не добавляется в таблицу как новая колонка.
#
# Зачем нужно:  когда старый индекс — это просто сбившиеся после фильтрации цифры, и они не несут никакой ценности. Просто нужно навести порядок и пронумеровать строки заново, не засоряя таблицу лишними колонками.

# %% [markdown]
# 💡 drop=True removes the old index instead of adding it as a new column.

# %% [markdown]
# - ### Adding a New Column
#
# We can add a new column to a DataFrame by assigning values to a new column name.

# %% [markdown]
# 🧩 Let's add a new Boolean column indicating whether an observation is from a weekend.

# %%
df["Date"].dt.dayofweek
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 8755    4
# 8756    4
# 8757    4
# 8758    4
# 8759    4
# Name: Date, Length: 8760, dtype: int32

# %% [markdown]
# 💡dayofweek returns the day of the week as a number, where Monday is 0 and Sunday is 6.

# %%
df["Date"].dt.dayofweek.unique()
# Out:
# array([4, 5, 6, 0, 1, 2, 3], dtype=int32)

# %%
df["Weekend"] = df["Date"].dt.dayofweek >= 5

# %%
df.head()
# Out:
#         Date  Rented_bike_count  Hour  Temperature  Humidity  Wind_speed  \
# 0 2017-12-01                254     0         -5.2        37         2.2
# 1 2017-12-01                204     1         -5.5        38         0.8
# 2 2017-12-01                173     2         -6.0        39         1.0
# 3 2017-12-01                107     3         -6.2        40         0.9
# 4 2017-12-01                 78     4         -6.0        36         2.3
#
#    Visibility  Dew_point_temp  Solar_radiation  Rainfall  Snowfall Seasons  \
# 0        2000           -17.6              0.0       0.0       0.0  Winter
# 1        2000           -17.6              0.0       0.0       0.0  Winter
# 2        2000           -17.7              0.0       0.0       0.0  Winter
# 3        2000           -17.6              0.0       0.0       0.0  Winter
# 4        2000           -18.6              0.0       0.0       0.0  Winter
#
#       Holiday Functional_day  Weekend
# ...

# %% [markdown]
# <div style="background-color: #05c3de; padding: 10px;">
#     <h2><font color='white'>Grouping and Aggregating Data 🗂️</font></h2>
# </div>

# %% [markdown]
# <img src=https://assets.insightmediagroup.io/media/wp-content/uploads/2020/10/0DZ2msoVAFep3O73e.png >

# %% [markdown]
# - #### **Grouping** is the process of splitting data into groups based on the values of one or more columns.
# - #### **Aggregation** is the process of computing a summary statistic for each group.

# %% [markdown]
# 🧩 Let's calculate the average number of rented bikes for each season.

# %%
df.groupby("Seasons")["Rented_bike_count"].mean()
# Out:
# Seasons
# Autumn     819.597985
# Spring     730.031250
# Summer    1034.073370
# Winter     225.541204
# Name: Rented_bike_count, dtype: float64

# %% [markdown]
# 🧩 Let's calculate the median number of rented bikes for each season and sort the results.

# %%
df.groupby("Seasons")["Rented_bike_count"].median().sort_values()
# Out:
# Seasons
# Winter    203.0
# Spring    583.0
# Autumn    763.5
# Summer    905.5
# Name: Rented_bike_count, dtype: float64

# %% [markdown]
# 💡 By default, sort_values() sorts values in ascending order.

# %%
df.groupby("Seasons")["Rented_bike_count"].median().sort_values(ascending=False)
# Out:
# Seasons
# Summer    905.5
# Autumn    763.5
# Spring    583.0
# Winter    203.0
# Name: Rented_bike_count, dtype: float64

# %% [markdown]
# 🧩 Let's calculate the average number of rented bikes for each hour of the day.

# %%
hourly_demand = df.groupby("Hour")["Rented_bike_count"].mean()

# %% [markdown]
# <div style="background-color: #05c3de; padding: 10px;">
#     <h2><font color='white'> Data Visualisation 📊 </font></h2>
# </div>

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# - #### Line plot

# %% [markdown]
# 🧩 Let's visualize the average number of rented bikes for each hour of the day.

# %%
plt.figure(figsize=(10, 5))
plt.plot(hourly_demand.index, hourly_demand.values, marker="o")

plt.xlabel("Hour")
plt.ylabel("Average rented bike count")
plt.title("Average Bike Demand During the Day")

plt.show()

# %% [markdown]
# By default, Matplotlib connects the observations with a line.

# %% [markdown]
# We can plot multiple lines in the same figure. Each plot() call adds another line to the current plot.

# %%
hourly_mean = df.groupby("Hour")["Rented_bike_count"].mean()
hourly_max = df.groupby("Hour")["Rented_bike_count"].max()

# %%
plt.figure(figsize=(10, 5))

plt.plot(hourly_mean.index, hourly_mean.values, label="Mean",marker="o")

plt.plot(hourly_max.index, hourly_max.values,label="Maximum", marker="^")

plt.xlabel("Hour")
plt.ylabel("Rented bike count")
plt.title("Bike Demand During the Day")
plt.legend()

plt.show()

# %% [markdown]
# #### Scatter plot

# %% [markdown]
# 🧩 Let's visualize the relationship between Temperature and Rented_bike_count.

# %%
plt.figure(figsize=(10, 6))

plt.scatter(df.Temperature, df.Rented_bike_count)

plt.title("Temperature vs. Bike Rentals")
plt.xlabel("Temperature (°C)")
plt.ylabel("Rented Bike Count")

plt.show()

# %% [markdown]
# #### Histogram

# %%
plt.hist(df["Rented_bike_count"], bins=20)
plt.xlabel("Rented bike count")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Seaborn
#
# - We can create similar plots using Seaborn.
# - It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
import seaborn as sns

# %% [markdown]
# Scatter plot

# %%
sns.scatterplot(data=df,x="Temperature",y="Rented_bike_count")
# Out:
# <Axes: xlabel='Temperature', ylabel='Rented_bike_count'>

# %% [markdown]
# 🧩 Let's color the data points according to season.

# %%
sns.scatterplot(data=df,x="Temperature",y="Rented_bike_count",hue="Seasons")
# Out:
# <Axes: xlabel='Temperature', ylabel='Rented_bike_count'>

# %% [markdown]
# Histogram

# %%
sns.histplot(data=df,x="Rented_bike_count",bins=20)
# Out:
# <Axes: xlabel='Rented_bike_count', ylabel='Count'>

# %% [markdown]
# Barplot

# %% [markdown]
# 🧩 Let's compare the average number of rented bikes across seasons.

# %%
sns.barplot(data=df,x="Seasons",y="Rented_bike_count",errorbar=None)
# Out:
# <Axes: xlabel='Seasons', ylabel='Rented_bike_count'>

# %% [markdown]
# 💡 By default, sns.barplot() shows the mean value of the numerical variable for each category.

# %% [markdown]
# ### Interactive Plotly chart

# %% [markdown]
# Plotly creates interactive charts: you can hover over points, zoom, pan, and hide categories from the legend. We will use the high-level `plotly.express` interface.

# %%
import plotly.express as px

# %%
fig = px.scatter(df,
    x="Temperature",
    y="Rented_bike_count",
    color="Seasons",
    hover_data=["Hour"],
    title="Bike rentals by temperature and season",
    labels={"Temperature": "Temperature (°C)",
        "Rented_bike_count": "Rented bike count",
        "Seasons": "Season",},
    opacity=0.65,)

fig.show()

# %% [markdown]
#  Create a scatter plot with:
#
# - `Temperature` on the x-axis,
# - `Rented_bike_count` on the y-axis,
# - points coloured by `Seasons`,
# - `Hour` displayed in the hover tooltip,
# - a meaningful title.
#
# Store the chart in `fig`, then display it with `fig.show()`. Explore it by hovering over a point and zooming into a region.

# %% [markdown]
# ## Exit ticket 🎫

# %% [markdown]
# #### 🧩 PRACTICE 1

# %% [markdown]
# - Create a Boolean mask for observations where more than 1,000 bikes were rented, the temperature was above 20 °C, and there was no rainfall.
#
# - Use the mask to create a new column called High_demand
# - How many high-demand observations are in the dataset?

# %%
mask = (df["Temperature"] > 20) & (df["Rented_bike_count"] > 1000) & (df["Rainfall"] == 0)

# %%
df["High_demand"] = mask
df["High_demand"].sum()
# Out:
# np.int64(1494)

# %% [markdown]
# #### 🧩 PRACTICE 2
#
# - Create a bar chart showing the average number of rented bikes for each season.
#
# - Use `Holiday` to distinguish between holidays and non-holidays using different colors.
#
# - Add an appropriate title and axis labels.

# %%
sns.barplot(data=df, x="Seasons", y="Rented_bike_count", hue="Holiday")

plt.title("Average Rented Bikes per Season")
plt.xlabel("Season")
plt.ylabel("Average Bike Count")

plt.show()

# %% [markdown]
# ---
# #### <font color='#05c3de'>To be continued...</font>

# %% [markdown]
# ![images.jpg](attachment:images.jpg)
